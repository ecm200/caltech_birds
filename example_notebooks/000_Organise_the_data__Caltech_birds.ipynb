# %% [markdown]
# # Caltech UCSD Birds 200 2011 (CUB-200-2011)
#
# ## Part 1 - Downloading and sorting the dataset
#
# This notebook is for sorting the image and label data from Caltech UCSD ready for use with PyTorch data loading utilities.
#
# This is the first stage of our roadmap for building and understanding a birds image classifier:
#
# ![RoadMapImage](../docs/birds_roadmap.png)
#
# To download the data click on the following links:
#
#    1. Images and annotations [Link](http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz)
#
#        *(Alternatively these can be downloaded from the releases page of this repository: [ecm200 CalTech Birds](https://github.com/ecm200/caltech_birds))*
#        *Two files are available:
#
#                CUB_200_2011_data_original.zip - which contains all the images and ancillary data listed below, with exec.
#
#                CUB_200_2011_data_original.zip - this contains the sorted images in train and test folders, given by the train_test_split.txt*
#
#
#    2. Segmentations (optional, not need for this work) [Link](http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/segmentations.tgz)
#
# Place the files into the root of the cloned caltech_birds repo file structure.
#
# Unzip the dowloaded zip files into cloned repository structure that replicates the project structure:
#
#     caltech_birds-|
#         cub_tools-|
#         data-|   ** SEPARATE DOWNLOAD FROM RELEASES **
#             attributes-|
#             images_orig-|
#             images-|
#             parts-|
#             attributes.txt
#             bounding_boxes.txt
#             classes.txt
#             image_class_labels.txt
#             images.txt
#             README
#             train_test_split.txt
#         example_notebooks-|  ** DIRECTORY CONTAINING THIS NOTEBOOK **
#         models-|   ** SEPARATE DOWNLOAD FROM RELEASES **
#             classification-|
#                 #modelname1#-|
#                 #modelname2#-|
#         notebooks-|
#         scripts-|
#
# This section covers the contents of the directories with a brief description.
#
# **example_notebooks** directory contains the set of walk through notebooks, of which this is the first, for following the full workflow of producing a bird classifier using deep neural networks, using a ResNet152 deep neural network architecture.
#
# **notebooks** directory contain the Jupyter notebooks where the majority of the visualisation and high level code will be maintained.
#
# **scripts** directory contains the computationally intensive functions which take longer to run, and are better executed in a python script, using some form of terminal persistance method to keep the computational session open whilst the program is running. In most examples in this project, it is the training of the Neural Networks where this will be achieved, that can typically take a few hours, to a day or so. I prefer to use [TMUX](https://github.com/tmux/tmux/wiki/Getting-Started), which is a Linux utility that maintains separate terminal sessions that can be attached and detached to any linux terminal session once opened. This way, you can execute long running python training scripts inside a TMUX session, detach it, close down the terminal session and let the process run. You can then start a new terminal session, and then attach the running TMUX session to view the progress of the executed script, including all its output to terminal history.
#
# **cub_tools** directory contains all the utility functions that have been developed to process, visualise, train and evaluate CNN models, as well results post processing have been contained. It has been converted into a python package that can be installed in the local environment by running in the **cub_tools** directory, *pip install -e .*. The functions can then be accessed using the cub_tools module import as ***import cub_tools***.
#
# **models** directory contains the results from the model training processes, and also any other outputs from the evaluation processes including model predictions, network feature maps etc. **All model outputs used by the example notebooks can be downloaded from the release folder of the Github repo.** The models zip should be placed in the root of the repo directory structure and unziped to create a models directory with the ResNet152 results contained within. Other models are also available including PNASNET, Inception V3 and V4, GoogLenet and ResNeXt variants.
#
# ## Dataset details
#
#
# Caltech-UCSD Birds-200-2011 (CUB-200-2011) is an extended version of the CUB-200 dataset, with roughly double the number of images per class and new part location annotations. For detailed information about the dataset, please see the technical report linked below.
#
# Number of categories: 200
#
# Number of images: 11,788
#
# Annotations per image: 15 Part Locations, 312 Binary Attributes, 1 Bounding Box
#
# Some related datasets are Caltech-256, the Oxford Flower Dataset, and Animals with Attributes. More datasets are available at the Caltech Vision Dataset Archive.

# %% [markdown]
# ## Notebook setup
#
# ### Modules and externals

# %%
import os
import pandas as pd
import shutil

# %% [markdown]
# ### Runtime setup
#
# **root_dir** is the path to the directory where the downloaded CUB-200-2011 data resides.
#
# **orig_images_folder** is the folder name that all the images are stored in. By default this is "images", and in this examples it has been renamed to **images_orig**
#
# **new_images_folder** is the folder name where the images will be sorted into train and test sets folder structures for PyTorch dataloading utility that creates a dataloading object.
#
# The reason for sorting the input images into train and test directories, based on the supplied *train_test_split.txt* file, allows for the use of the PyTorch Torchvision data loading utility, [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder).
#
# This script will take the directory location of the images as downloaded from the src in **images_orig**, and sort them into train and test sets in the **images** folder. The sorting of the images into training and test sets will be governed by the datasets provided designation, found in the ancillary text file, *train_test_split.txt*. This file contains *image_ID* and a binary flag *is_test_image*, where 1 indicates it is a test image, 0 a training image. The file *images.txt* gives the path to the image for each *image_ID*.

# %%
root_dir = '../data'
orig_images_folder = 'images_orig'
new_images_folder = 'images'

# %%
data_dir = os.path.join(root_dir,orig_images_folder)
new_data_dir = os.path.join(root_dir,new_images_folder)

# %% [markdown]
# ### Load the relevant data from text files
#
# This section loads the image files paths with *image_ID* (images.txt), and *train_test_split.txt* designation into Pandas Dataframes for later use.

# %%
image_fnames = pd.read_csv(filepath_or_buffer=os.path.join(root_dir,'images.txt'), 
                          header=None, 
                          delimiter=' ', 
                          names=['Img ID', 'file path'])

image_fnames['is training image?'] = pd.read_csv(filepath_or_buffer=os.path.join(root_dir,'train_test_split.txt'), 
                                                 header=None, delimiter=' ', 
                                                 names=['Img ID','is training image?'])['is training image?']

# %% [markdown]
# Create the new directories for the sorted data.

# %%
os.makedirs(os.path.join(new_data_dir,'train'), exist_ok=True)
os.makedirs(os.path.join(new_data_dir,'test'), exist_ok=True)

# %% [markdown]
# ### Sort images into train and test folders based on predefined split
#
# Using the train_test_split.txt file, each image is copied either to the relevant folder in either the train or test folders.
# The resulting file will have the following structure:
#
#     images-|
#         train-|
#             #classname1#-|
#                 image-1.jpg
#                 image-2.jpg
#             #classname2-|
#                 image-1.jpg
#                 image-2.jpg
#             |
#             |
#             #classnameN-|
#                 image-1.jpg
#                 image-2.jpg
#         test-|
#             #classname1#-|
#                 image-1.jpg
#                 image-2.jpg
#             #classname2-|
#                 image-1.jpg
#                 image-2.jpg
#             |
#             |
#             #classnameN-|
#                 image-1.jpg
#                 image-2.jpg

# %%
for i_image, image_fname in enumerate(image_fnames['file path']):
    if image_fnames['is training image?'].iloc[i_image]:
        new_dir = os.path.join(new_data_dir,'train',image_fname.split('/')[0])
        os.makedirs(new_dir, exist_ok=True)
        shutil.copy(src=os.path.join(data_dir,image_fname), dst=os.path.join(new_dir, image_fname.split('/')[1]))
        print(i_image, ':: Image is in training set. [', bool(image_fnames['is training image?'].iloc[i_image]),']')
        print('Image:: ', image_fname)
        print('Destination:: ', new_dir)
    else:
        new_dir = os.path.join(new_data_dir,'test',image_fname.split('/')[0])
        os.makedirs(new_dir, exist_ok=True)
        shutil.copy(src=os.path.join(data_dir,image_fname), dst=os.path.join(new_dir, image_fname.split('/')[1]))
        print(i_image, ':: Image is in testing set. [', bool(image_fnames['is training image?'].iloc[i_image]),']')
        print('Source Image:: ', image_fname)
        print('Destination:: ', new_dir)
# Out:
# 0 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0046_18.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 1 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0009_34.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 2 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0002_55.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 3 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0074_59.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 4 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0014_89.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 5 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0085_92.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 6 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0031_100.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 7 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0051_796103.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 8 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0010_796097.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 9 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0025_796057.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 10 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0023_796059.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 11 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0086_796062.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 12 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0049_796063.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 13 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0006_796065.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 14 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0040_796066.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 15 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0016_796067.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 16 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0065_796068.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 17 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0089_796069.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 18 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0042_796071.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 19 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0067_170.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 20 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0060_796076.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 21 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0090_796077.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 22 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0056_796078.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 23 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0061_796082.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 24 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0008_796083.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 25 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0033_796086.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 26 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0024_796089.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 27 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0005_796090.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 28 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0026_796095.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 29 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0080_796096.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 30 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0047_796064.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 31 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0017_796098.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 32 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0064_796101.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 33 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0076_417.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 34 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0019_796104.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 35 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0057_796106.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 36 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0041_796108.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 37 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0053_796109.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 38 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0001_796111.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 39 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0071_796113.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 40 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0077_796114.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 41 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0032_796115.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 42 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0038_212.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 43 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0037_796120.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 44 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0082_796121.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 45 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0079_796122.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 46 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0050_796125.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 47 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0078_796126.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 48 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0036_796127.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 49 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0045_796129.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 50 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0039_796132.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 51 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0088_796133.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 52 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0068_796135.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 53 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0003_796136.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 54 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0007_796138.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 55 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0069_796139.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 56 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0035_796140.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 57 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0063_796141.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 58 :: Image is in testing set. [ False ]
# Source Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0058_796074.jpg
# Destination::  ../data/images_test/test/001.Black_footed_Albatross
# 59 :: Image is in training set. [ True ]
# Image::  001.Black_footed_Albatross/Black_Footed_Albatross_0081_426.jpg
# Destination::  ../data/images_test/train/001.Black_footed_Albatross
# 60 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0002_1027.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 61 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0003_1033.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 62 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0082_524.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 63 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0044_784.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 64 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0070_788.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 65 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0050_870.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 66 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0071_792.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 67 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0053_543.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 68 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0081_800.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 69 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0001_545.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 70 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0023_1059.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 71 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0065_809.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 72 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0061_563.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 73 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0085_564.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 74 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0005_565.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 75 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0060_777.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 76 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0055_570.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 77 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0025_571.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 78 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0080_821.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 79 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0092_834.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 80 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0013_910.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 81 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0091_602.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 82 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0102_611.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 83 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0099_869.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 84 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0017_614.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 85 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0047_619.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 86 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0035_876.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 87 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0098_621.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 88 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0088_883.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 89 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0034_628.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 90 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0104_630.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 91 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0058_637.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 92 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0028_643.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 93 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0033_658.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 94 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0075_668.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 95 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0076_671.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 96 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0096_673.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 97 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0064_674.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 98 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0039_924.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 99 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0049_918.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 100 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0012_696.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 101 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0056_500.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 102 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0037_699.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 103 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0006_702.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 104 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0073_927.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 105 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0042_801.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 106 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0004_930.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 107 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0093_725.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 108 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0068_726.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 109 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0040_472.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 110 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0100_735.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 111 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0021_737.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 112 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0029_482.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 113 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0059_488.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 114 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0018_492.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 115 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0083_756.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 116 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0094_1013.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 117 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0103_504.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 118 :: Image is in testing set. [ False ]
# Source Image::  002.Laysan_Albatross/Laysan_Albatross_0079_506.jpg
# Destination::  ../data/images_test/test/002.Laysan_Albatross
# 119 :: Image is in training set. [ True ]
# Image::  002.Laysan_Albatross/Laysan_Albatross_0051_1020.jpg
# Destination::  ../data/images_test/train/002.Laysan_Albatross
# 120 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0038_1065.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 121 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0031_1066.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 122 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0001_1071.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 123 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0016_1075.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 124 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0043_1076.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 125 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0003_1078.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 126 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0077_1080.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 127 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0063_1101.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 128 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0044_1105.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 129 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0071_1116.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 130 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0070_796346.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 131 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0030_1122.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 132 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0054_796347.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 133 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0033_1128.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 134 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0048_1130.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 135 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0032_1149.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 136 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0034_1154.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 137 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0055_1160.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 138 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0024_1161.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 139 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0045_1162.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 140 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0073_1171.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 141 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0074_1221.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 142 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0021_796339.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 143 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0005_796342.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 144 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0064_796343.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 145 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0042_1210.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 146 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0046_1211.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 147 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0017_796349.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 148 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0049_796350.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 149 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0050_796351.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 150 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0075_796352.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 151 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0068_796353.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 152 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0057_796354.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 153 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0010_796355.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 154 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0029_796357.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 155 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0069_796358.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 156 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0020_796359.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 157 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0058_796360.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 158 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0025_796361.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 159 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0041_796364.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 160 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0076_796365.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 161 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0004_796366.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 162 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0065_796367.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 163 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0072_796371.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 164 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0007_796372.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 165 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0014_796373.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 166 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0051_796374.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 167 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0040_796375.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 168 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0067_796376.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 169 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0066_796382.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 170 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0036_796387.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 171 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0079_796389.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 172 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0006_796390.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 173 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0019_796391.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 174 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0002_796395.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 175 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0022_796398.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 176 :: Image is in training set. [ True ]
# Image::  003.Sooty_Albatross/Sooty_Albatross_0023_796401.jpg
# Destination::  ../data/images_test/train/003.Sooty_Albatross
# 177 :: Image is in testing set. [ False ]
# Source Image::  003.Sooty_Albatross/Sooty_Albatross_0013_796402.jpg
# Destination::  ../data/images_test/test/003.Sooty_Albatross
# 178 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0068_1538.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 179 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0094_1540.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 180 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0033_1494.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 181 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0069_1546.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 182 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0080_1549.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 183 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0071_1559.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 184 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0037_1560.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 185 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0017_1561.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 186 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0105_1562.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 187 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0090_1567.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 188 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0019_1585.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 189 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0031_1588.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 190 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0107_1590.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 191 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0035_1591.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 192 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0109_1592.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 193 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0036_1604.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 194 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0085_1612.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 195 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0018_1613.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 196 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0007_1615.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 197 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0075_1617.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 198 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0029_1620.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 199 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0108_1639.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 200 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0100_1646.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 201 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0051_1650.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 202 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0015_1653.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 203 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0076_1661.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 204 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0046_1663.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 205 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0002_1670.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 206 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0053_1672.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 207 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0088_1678.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 208 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0072_1696.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 209 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0082_1697.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 210 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0101_1700.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 211 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0010_1704.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 212 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0047_1706.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 213 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0040_1715.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 214 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0077_1724.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 215 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0091_1728.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 216 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0074_1730.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 217 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0044_1731.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 218 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0059_1480.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 219 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0023_1485.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 220 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0004_1528.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 221 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0056_1493.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 222 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0005_1750.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 223 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0058_1751.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 224 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0027_1754.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 225 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0014_1755.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 226 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0055_1501.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 227 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0065_1502.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 228 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0060_1505.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 229 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0006_1763.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 230 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0087_1765.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 231 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0061_1510.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 232 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0062_1767.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 233 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0092_1516.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 234 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0032_1776.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 235 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0009_1522.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 236 :: Image is in testing set. [ False ]
# Source Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0078_1780.jpg
# Destination::  ../data/images_test/test/004.Groove_billed_Ani
# 237 :: Image is in training set. [ True ]
# Image::  004.Groove_billed_Ani/Groove_Billed_Ani_0012_1784.jpg
# Destination::  ../data/images_test/train/004.Groove_billed_Ani
# 238 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0006_1813.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 239 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0042_794902.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 240 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0061_794904.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 241 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0018_1817.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 242 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0010_794907.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 243 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0041_794910.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 244 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0029_1824.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 245 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0044_1825.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 246 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0013_794914.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 247 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0047_794918.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 248 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0005_794922.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 249 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0019_794925.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 250 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0011_794927.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 251 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0059_794929.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 252 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0032_794931.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 253 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0057_794932.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 254 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0021_794938.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 255 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0045_794940.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 256 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0001_794941.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 257 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0039_794944.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 258 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0074_794949.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 259 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0028_794951.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 260 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0052_794952.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 261 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0012_794960.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 262 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0003_794962.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 263 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0033_794964.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 264 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0053_794966.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 265 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0062_794968.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 266 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0073_785248.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 267 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0067_785249.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 268 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0066_785251.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 269 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0076_785252.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 270 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0068_785253.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 271 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0071_785255.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 272 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0077_785257.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 273 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0069_785258.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 274 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0075_785259.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 275 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0072_785260.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 276 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0070_785261.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 277 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0063_794901.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 278 :: Image is in testing set. [ False ]
# Source Image::  005.Crested_Auklet/Crested_Auklet_0036_794905.jpg
# Destination::  ../data/images_test/test/005.Crested_Auklet
# 279 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0030_794937.jpg
# Destination::  ../data/images_test/train/005.Crested_Auklet
# 280 :: Image is in training set. [ True ]
# Image::  005.Crested_Auklet/Crested_Auklet_0040_794912.jpg
# ...
# Image::  199.Winter_Wren/Winter_Wren_0128_190093.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11696 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0131_190061.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11697 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0015_190099.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11698 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0090_190104.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11699 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0111_189596.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11700 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0021_189597.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11701 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0037_190123.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11702 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0087_190135.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11703 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0097_190139.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11704 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0033_189635.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11705 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0066_189637.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11706 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0141_190152.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11707 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0051_189990.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11708 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0004_189670.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11709 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0065_189675.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11710 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0048_189683.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11711 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0093_189686.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11712 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0071_189689.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11713 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0086_189692.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11714 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0005_189750.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11715 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0030_190311.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11716 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0026_189816.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11717 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0126_190342.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11718 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0116_189834.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11719 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0003_189838.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11720 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0129_189843.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11721 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0109_189850.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11722 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0132_189861.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11723 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0029_190376.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11724 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0142_190379.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11725 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0077_190366.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11726 :: Image is in testing set. [ False ]
# Source Image::  199.Winter_Wren/Winter_Wren_0047_190390.jpg
# Destination::  ../data/images_test/test/199.Winter_Wren
# 11727 :: Image is in training set. [ True ]
# Image::  199.Winter_Wren/Winter_Wren_0118_189805.jpg
# Destination::  ../data/images_test/train/199.Winter_Wren
# 11728 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0020_190720.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11729 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0016_190986.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11730 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0077_190990.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11731 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0104_190489.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11732 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0114_190501.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11733 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0090_190503.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11734 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0039_190513.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11735 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0003_190521.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11736 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0019_190524.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11737 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0081_190525.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11738 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0028_190527.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11739 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0099_190531.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11740 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0125_190902.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11741 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0050_190535.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11742 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0106_190989.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11743 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0025_190547.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11744 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0118_190805.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11745 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0015_190556.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11746 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0045_190563.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11747 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0035_190567.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11748 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0111_190569.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11749 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0122_190570.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11750 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0112_190571.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11751 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0010_190572.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11752 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0092_190573.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11753 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0006_190576.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11754 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0009_190578.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11755 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0031_190582.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11756 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0059_190584.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11757 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0032_190592.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11758 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0088_190594.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11759 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0121_190597.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11760 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0046_190446.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11761 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0004_190606.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11762 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0093_190609.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11763 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0027_190869.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11764 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0126_190407.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11765 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0086_190639.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11766 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0075_190900.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11767 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0066_190646.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11768 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0018_190904.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11769 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0054_190398.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11770 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0021_190655.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11771 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0069_190400.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11772 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0011_190401.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11773 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0072_190402.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11774 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0029_190403.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11775 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0080_190663.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11776 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0071_190665.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11777 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0087_190414.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11778 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0070_190678.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11779 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0040_190427.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11780 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0098_190430.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11781 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0094_190690.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11782 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0063_190440.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11783 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0037_190698.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11784 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0058_190958.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11785 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0008_190703.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
# 11786 :: Image is in training set. [ True ]
# Image::  200.Common_Yellowthroat/Common_Yellowthroat_0049_190708.jpg
# Destination::  ../data/images_test/train/200.Common_Yellowthroat
# 11787 :: Image is in testing set. [ False ]
# Source Image::  200.Common_Yellowthroat/Common_Yellowthroat_0055_190967.jpg
# Destination::  ../data/images_test/test/200.Common_Yellowthroat
